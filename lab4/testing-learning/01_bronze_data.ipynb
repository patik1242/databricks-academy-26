# %%
CATALOG = "academy"
RAW_SCHEMA = "lab4"
BRONZE_SCHEMA = "lab4_bronze"
TITLE = "netflix_titles"

BRONZE_TABLE = f"{CATALOG}.{BRONZE_SCHEMA}.netflix_titles"

# %%
bronze_df = (
    spark.read
        .format("csv")
        .option("header", "true")
        .option("inferSchema", "false")
        .option("quote", '"')
        .option("escape", '"')
        .option("multiLine", "true")
        .option("mode", "PERMISSIVE")
        .load(SOURCE_PATH)
)

# %%
bronze_df = (
    bronze_df
        .withColumn("_ingestion_time", F.current_timestamp()) 
)

# %%
display(bronze_df)

# %%
bronze_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(BRONZE_TABLE)
