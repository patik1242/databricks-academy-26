# %%
from pyspark.sql import functions as F

CATALOG = "academy"
SILVER_SCHEMA = "lab4_silver"
TABLE_NAME = "netflix_titles"

SILVER_TABLE = f"{CATALOG}.{SILVER_SCHEMA}.{TABLE_NAME}"

# %%
# %sql
CREATE TABLE academy.lab4_silver.netflix_titles_backup
AS
SELECT *
FROM academy.lab4_silver.netflix_titles;

# %%
silver_df = spark.table(SILVER_TABLE)

silver_df.printSchema()

# %%
# %sql
ALTER TABLE academy.lab4_silver.netflix_titles SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name'
)

# %%
# %sql
ALTER TABLE academy.lab4_silver.netflix_titles RENAME COLUMN rating TO age_rating

# %%
# %sql
ALTER TABLE academy.lab4_silver.netflix_titles DROP COLUMN director
