# %%
source_path = ("/Volumes/dbr_dev/pkustra555_bronze/streaming_lab/generated/social_media_addiction_mental_wellbeing.csv")
output_path = ("/Volumes/dbr_dev/pkustra555_bronze/streaming_lab/generated/batches")

input_path = "/Volumes/dbr_dev/pkustra555_bronze/streaming_lab/input/"

# %%
df = spark.read.option("header", True).csv(source_path) 
print(df.count())
print(len(df.columns))

# %%
df.repartition(1000).write.mode("overwrite").option("header", True).csv(output_path)

# %%
files = dbutils.fs.ls(output_path)
csv_files = [f for f in files if f.name.endswith(".csv")]

print(len(csv_files))

# %%
dbutils.fs.cp(output_path, input_path, recurse=True)

# %%
input_files = dbutils.fs.ls(input_path)
input_csv_files = [f for f in input_files if f.name.endswith(".csv")]

print(len(input_csv_files))

# %%
display(dbutils.fs.ls(input_path)[:10])
